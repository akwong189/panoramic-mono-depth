# %%
import pandas as pd

# %%
train = pd.read_csv("./splits/kitti_train.csv", index_col=0)
test = pd.read_csv("./splits/kitti_test.csv", index_col=0)

# %%
train.head()
# Out:
#                                               images  \
# 0  2011_10_03/2011_10_03_drive_0042_sync/image_03...
# 1  2011_10_03/2011_10_03_drive_0042_sync/image_03...
# 2  2011_10_03/2011_10_03_drive_0042_sync/image_03...
# 3  2011_10_03/2011_10_03_drive_0042_sync/image_03...
# 4  2011_10_03/2011_10_03_drive_0042_sync/image_03...
#
#                                                depth
# 0  2011_10_03_drive_0042_sync/proj_depth/groundtr...
# 1  2011_10_03_drive_0042_sync/proj_depth/groundtr...
# 2  2011_10_03_drive_0042_sync/proj_depth/groundtr...
# 3  2011_10_03_drive_0042_sync/proj_depth/groundtr...
# 4  2011_10_03_drive_0042_sync/proj_depth/groundtr...

# %%
test.head()
# Out:
#                                               images  \
# 0  2011_09_26/2011_09_26_drive_0036_sync/image_03...
# 1  2011_09_26/2011_09_26_drive_0036_sync/image_03...
# 2  2011_09_26/2011_09_26_drive_0036_sync/image_03...
# 3  2011_09_26/2011_09_26_drive_0036_sync/image_03...
# 4  2011_09_26/2011_09_26_drive_0036_sync/image_03...
#
#                                                depth
# 0  2011_09_26_drive_0036_sync/proj_depth/groundtr...
# 1  2011_09_26_drive_0036_sync/proj_depth/groundtr...
# 2  2011_09_26_drive_0036_sync/proj_depth/groundtr...
# 3  2011_09_26_drive_0036_sync/proj_depth/groundtr...
# 4  2011_09_26_drive_0036_sync/proj_depth/groundtr...

# %%
import tensorflow as tf
import numpy as np
import random

def preprocess_color(image, flip=False, shape=None, **kwargs):
    if flip:
        image = tf.image.flip_left_right(image)
        
    if shape:
        h, w, _ = image.shape
        
        max_height = h - shape[0]
        max_width = w - shape[1]
        
        random_height = np.random.randint(0, max_height)
        random_width = np.random.randint(0, max_width)
        
        print(random_height, random_width)
        
        image = image[random_height:random_height+shape[0], random_width:random_width+shape[1]]

    if type(image) is np.ndarray:
        return image
    return image.numpy(), (random_height, random_width)


def load_color_image(filename, **kwargs):
    image = tf.io.read_file(filename)
    image = tf.io.decode_image(image, channels=3, expand_animations=False)
    image = tf.cast(image, tf.float32)
    return image


def load_color(filename, path="/data3/awong/kitti_raw/", flip=False, shape=(256, 640), **kwargs):
    img = load_color_image(path + filename)
    return preprocess_color(img, flip, shape)

# %%
# def preprocess_depth(image, flip=False, shape=None, random_loc=None, **kwargs):
#     if flip:
#         image = tf.image.flip_left_right(image)
        
#     if shape:
#         h, w = shape
#         ran_h, ran_w = random_loc
#         image = image[h:h+ran_h, w:w+ran_w]

#     if type(image) is np.ndarray:
#         return image
#     return image.numpy()

def preprocess_depth(image, flip=False, shape=None, rand_shape=(0,0), **kwargs):
    if flip:
        image = tf.image.flip_left_right(image)
        
    if shape:
        random_height, random_width = rand_shape
        print(random_height, random_width)
        image = image[random_height:random_height+shape[0], random_width:random_width+shape[1]]

    if type(image) is np.ndarray:
        return image
    return image.numpy()


def load_depth_image(filename, **kwargs):
    image = tf.io.read_file(filename)
    image = tf.io.decode_image(image, channels=1, expand_animations=False)
    image = tf.cast(image, tf.float32)
    return image


def load_depth(filename, split="train", path="/data3/awong/kitti/", flip=False, shape=(256, 640), rand_shape=(0,0), **kwargs):
    img = load_depth_image(path + f"{split}/" + filename)

    return preprocess_depth(img, flip, shape, rand_shape)

# %%
import matplotlib.pyplot as plt

def random_location(image):
    h, w, _ = image.shape

    max_height = h - shape[0]
    max_width = w - shape[1]

    random_height = np.random.randint(0, max_height)
    random_width = np.random.randint(0, max_width)

    print(random_height, random_width)
    
    return random_height, random_width
    
file = train["images"][0]
img, rand_shape = load_color(file)
img = (img - img.min()) / (img.max() - img.min())
print(img.shape)
plt.imshow(img)
# Out:
# 32 263
# (256, 640, 3)

# %%
file = train["depth"][0]
img = load_depth(file, rand_shape=rand_shape)
img = (img - img.min()) / (img.max() - img.min())
print(img.shape)
plt.imshow(img, cmap='gray')
# Out:
# 32 263
# (256, 640, 1)
