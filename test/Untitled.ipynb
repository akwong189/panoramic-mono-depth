# %%
import tensorflow as tf
from tensorflow import keras
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

class Depthwise_Seperable_Conv(keras.layers.Layer):
    def __init__(self, nin, nout):
        super(Depthwise_Seperable_Conv, self).__init__()
        self.depthwise = keras.layers.Conv2D(nin, kernel_size=3, padding='same', groups=nin)
        self.pointwise = keras.layers.Conv2D(nout, kernel_size=1, padding='same')
        
    def call(self, inputs):
        x = self.depthwise(inputs)
        x = self.pointwise(x)
        return x
    
class LIST(keras.layers.Layer):
    def __init__(self, in_channel, out_channel, k=4, nb=2):
        super(LIST, self).__init__()
        self.squeeze = keras.layers.Conv2D( 
            in_channel//k, 
            kernel_size=(1, 1),
            padding='same')
        self.bn1 = keras.layers.BatchNormalization()
        self.stream1 = keras.layers.Conv2D(
            out_channel//nb,
            kernel_size=1,
            padding='same'
        )
        self.bn2 = keras.layers.BatchNormalization()
        self.stream2 = Depthwise_Seperable_Conv(in_channel//k, out_channel//nb)
        self.bn3 = keras.layers.BatchNormalization()
        
    def call(self, inputs):
        x = self.squeeze(inputs)
        x = self.bn1(x)
        x = keras.activations.relu(x)
        
        # stream 1
        x1 = self.stream1(x)
        x1 = self.bn2(x1)
        x1 = keras.activations.relu(x1)
        
        # stream 2
        x2 = self.stream2(x)
        x2 = self.bn3(x2)
        x2 = keras.activations.relu(x2)
        
        return keras.layers.Concatenate(axis=3)([x1, x2])

class Group_Conv_Dilated(keras.layers.Layer):
    def __init__(self, in_channel, groups, dilation_factor):
        super(Group_Conv_Dilated, self).__init__()
        self.num_groups = groups
        self.dilation_factor = dilation_factor
        self.partial = in_channel // groups
        
    def call(self, inputs):
        groups = tf.split(inputs, self.num_groups, axis=3)
#         print([group.shape for group in groups])
        dil_conv = []
        
        for group in groups:
            dil_conv.append(keras.layers.Conv2D(
                self.partial, 
                kernel_size=(3,3), 
                dilation_rate=self.dilation_factor, 
                padding='same')(group)
            )
            
        return keras.layers.Concatenate(axis=3)(dil_conv)

class Channel_Shuffle(keras.layers.Layer):
    def __init__(self, groups):
        super(Channel_Shuffle, self).__init__()
        self.groups = groups
        
    def call(self, inputs):
        shape = inputs.shape[1:]
        
        x = keras.layers.Reshape([shape[0], shape[1], self.groups, shape[2]//self.groups])(inputs)
        x = keras.layers.Permute([1, 2, 4, 3])(x)
        x = keras.layers.Reshape([shape[0], shape[1], shape[2]])(x)
        return x
    
class Group_Conv_Normal(keras.layers.Layer):
    def __init__(self, in_channel, groups):
        super(Group_Conv_Normal, self).__init__()
        self.num_groups = groups
        self.partial = in_channel // groups
        
    def call(self, inputs):
        groups = tf.split(inputs, self.num_groups, axis=3)
#         print([group.shape for group in groups])
        dil_conv = []
        
        for group in groups:
            dil_conv.append(keras.layers.Conv2D(
                self.partial, 
                kernel_size=(1,1),
                padding='same')(group)
            )
            
        return keras.layers.Concatenate(axis=3)(dil_conv)
    
class GSAT(keras.layers.Layer):
    def __init__(self, in_channel, num_groups=8, dilation_factor=2):
        super(GSAT, self).__init__()
        self.dil_conv = Group_Conv_Dilated(in_channel, num_groups, dilation_factor)
        self.shuffle = Channel_Shuffle(num_groups)
        self.norm_conv = Group_Conv_Normal(in_channel, num_groups)
        self.bn = keras.layers.BatchNormalization()
        self.add = keras.layers.Add()

    def call(self, inputs):
        skip = inputs;
        
        x = self.dil_conv(inputs)
        x = self.shuffle(x)
        x = self.norm_conv(x)
        x = self.bn(x)
        x = self.add([skip, x])
        
        return keras.activations.relu(x)

class UpSampling(keras.layers.Layer):
    def __init__(self, in_channel, out_channel, stride=2):
        super(UpSampling, self).__init__()
        self.list = LIST(in_channel, out_channel)
        self.stride = stride
        
    def call(self, inputs, concat=None):
        shape = inputs.shape
        x = tf.image.resize(
            inputs, 
            [shape[1] * self.stride, shape[2] * self.stride]
        )
        
        if concat is not None:
            print("Concatenating")
            x = keras.layers.Concatenate(axis=3)([concat, x])
        
        x = self.list(x)
        return x
    
class DownSampling(keras.layers.Layer):
    def __init__(self, in_channel, out_channel, stride=2):
        super(DownSampling, self).__init__()
        self.list = LIST(in_channel, out_channel)
        self.stride = stride
        
    def call(self, inputs):
        shape = inputs.shape
        x = tf.image.resize(
            inputs, 
            [shape[1] // self.stride, shape[2] // self.stride]
        )
        x = self.list(x)
        return x

# %%
# https://medium.com/analytics-vidhya/creating-mobilenetsv2-with-tensorflow-from-scratch-c85eb8605342
def expansion_block(x, t, filters, block_id):
    prefix = 'block_{}_'.format(block_id)
    total_filters = t*filters
    x = keras.layers.Conv2D(total_filters, 1, padding='same', use_bias=False, name=prefix+'expand')(x)
    x = keras.layers.BatchNormalization(name=prefix +'expand_bn')(x)
    x = keras.layers.ReLU(6,name = prefix +'expand_relu')(x)
    return x

def depthwise_block(x, stride, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = DownSampling(x.shape[-1], x.shape[-1], stride=stride)(x)
#     x = keras.layers.DepthwiseConv2D(3,strides=(stride,stride),padding ='same', use_bias = False, name = prefix + 'depthwise_conv')(x)
    x = keras.layers.BatchNormalization(name=prefix +'dw_bn')(x)
    x = keras.layers.ReLU(6, name = prefix +'dw_relu')(x)
    return x

def projection_block(x, out_channels, block_id):
    prefix = 'block_{}_'.format(block_id)
    x = keras.layers.Conv2D(
        filters=out_channels,
        kernel_size = 1,
        padding='same',
        use_bias=False,
        name= prefix + 'compress'
    )(x)
    
    x = keras.layers.BatchNormalization(name=prefix +'compress_bn')(x)
    return x

def Bottleneck(x, t, filters, out_channels, stride, block_id, expand=False):
    y = expansion_block(x,t,filters,block_id)
    if expand:
        return y
    
    y = depthwise_block(y, stride, block_id)
    y = projection_block(y, out_channels,block_id)
    if y.shape[-1]==x.shape[-1]:
       y = keras.layers.Add()([x,y])
    return y

# %%
def MobileNetV2(input_shape=(224,224,3)):
    input_layer = keras.layers.Input(input_shape)
    
    x = keras.layers.Conv2D(32,3,strides=(2,2),padding='same', use_bias=False)(input_layer)
    x = keras.layers.BatchNormalization(name='conv1_bn')(x)
    x = keras.layers.ReLU(6, name='conv1_relu')(x)
    
    # 13 Bottlenecks
    x = depthwise_block(x, stride=1, block_id=0)
    x = projection_block(x, out_channels=16,block_id=0)
    x1 = Bottleneck(x, t = 6, filters = x.shape[-1], out_channels = 24, stride = 2,block_id = 1)
    x2 = Bottleneck(x1, t = 6, filters = x1.shape[-1], out_channels = 24, stride = 1,block_id = 2)
    x3 = Bottleneck(x2, t = 6, filters = x2.shape[-1], out_channels = 32, stride = 2,block_id = 3)
    x4 = Bottleneck(x3, t = 6, filters = x3.shape[-1], out_channels = 32, stride = 1,block_id = 4)
    x5 = Bottleneck(x4, t = 6, filters = x4.shape[-1], out_channels = 32, stride = 1,block_id = 5)
    x6 = Bottleneck(x5, t = 6, filters = x5.shape[-1], out_channels = 64, stride = 2,block_id = 6)
    x7 = Bottleneck(x6, t = 6, filters = x6.shape[-1], out_channels = 64, stride = 1,block_id = 7)
    x8 = Bottleneck(x7, t = 6, filters = x7.shape[-1], out_channels = 64, stride = 1,block_id = 8)
    x9 = Bottleneck(x8, t = 6, filters = x8.shape[-1], out_channels = 64, stride = 1,block_id = 9)
    x10 = Bottleneck(x9, t = 6, filters = x9.shape[-1], out_channels = 96, stride = 1,block_id = 10)
    x11 = Bottleneck(x10, t = 6, filters = x10.shape[-1], out_channels = 96, stride = 1,block_id = 11)
    x12 = Bottleneck(x10, t = 6, filters = x10.shape[-1], out_channels = 96, stride = 1,block_id = 12)
    x13_expand = Bottleneck(x11, t = 6, filters = x11.shape[-1], out_channels = 96, stride = 1,block_id = 13, expand=True)
    
    model = keras.Model(input_layer, x13_expand)
    return model
    
def OptimizedUNet(input_shape=(256,512,3)):
    base_model = MobileNetV2(input_shape)
    input_layer = base_model.input
    
    layer_names = ["block_6_expand_relu", "block_3_expand_relu", "block_1_expand_relu"]
    
    # Up Scaling
    x = base_model.output
    x = keras.layers.Conv2D(filters=512, kernel_size=(1,1), padding='same')(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = UpSampling(x.shape[-1], 256)(x, concat=base_model.get_layer(layer_names[0]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = UpSampling(x.shape[-1], 128)(x, concat=base_model.get_layer(layer_names[1]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = UpSampling(x.shape[-1], 64)(x, concat=base_model.get_layer(layer_names[2]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = UpSampling(x.shape[-1], 32)(x, concat=base_model.layers[0].output)
    output = keras.layers.Conv2D(filters=1, activation='sigmoid', kernel_size=(3,3), padding='same')(x)

    model = keras.Model(input_layer, output)
    return model

# %%
model = OptimizedUNet((256,512,3))
model.summary()
# Out:
# Concatenating
# Concatenating
# Concatenating
# Concatenating
# Model: "model_51"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_76 (InputLayer)           [(None, 256, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d_2187 (Conv2D)            (None, 128, 256, 32) 864         input_76[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 256, 32) 128         conv2d_2187[0][0]
# __________________________________________________________________________________________________
# conv1_relu (ReLU)               (None, 128, 256, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_33 (DownSampling) (None, 128, 256, 32) 792         conv1_relu[0][0]
# __________________________________________________________________________________________________
# block_0_dw_bn (BatchNormalizati (None, 128, 256, 32) 128         down_sampling_33[0][0]
# __________________________________________________________________________________________________
# block_0_dw_relu (ReLU)          (None, 128, 256, 32) 0           block_0_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_0_compress (Conv2D)       (None, 128, 256, 16) 512         block_0_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_0_compress_bn (BatchNorma (None, 128, 256, 16) 64          block_0_compress[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 256, 96) 1536        block_0_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_1_expand_bn (BatchNormali (None, 128, 256, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 256, 96) 0           block_1_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_34 (DownSampling) (None, 64, 128, 96)  5448        block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_dw_bn (BatchNormalizati (None, 64, 128, 96)  384         down_sampling_34[0][0]
# __________________________________________________________________________________________________
# block_1_dw_relu (ReLU)          (None, 64, 128, 96)  0           block_1_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_1_compress (Conv2D)       (None, 64, 128, 24)  2304        block_1_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_1_compress_bn (BatchNorma (None, 64, 128, 24)  96          block_1_compress[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 128, 144) 3456        block_1_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_2_expand_bn (BatchNormali (None, 64, 128, 144) 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 128, 144) 0           block_2_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_35 (DownSampling) (None, 64, 128, 144) 11628       block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_dw_bn (BatchNormalizati (None, 64, 128, 144) 576         down_sampling_35[0][0]
# __________________________________________________________________________________________________
# block_2_dw_relu (ReLU)          (None, 64, 128, 144) 0           block_2_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_2_compress (Conv2D)       (None, 64, 128, 24)  3456        block_2_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_2_compress_bn (BatchNorma (None, 64, 128, 24)  96          block_2_compress[0][0]
# __________________________________________________________________________________________________
# add_413 (Add)                   (None, 64, 128, 24)  0           block_1_compress_bn[0][0]
#                                                                  block_2_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 128, 144) 3456        add_413[0][0]
# __________________________________________________________________________________________________
# block_3_expand_bn (BatchNormali (None, 64, 128, 144) 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 128, 144) 0           block_3_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_36 (DownSampling) (None, 32, 64, 144)  11628       block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_dw_bn (BatchNormalizati (None, 32, 64, 144)  576         down_sampling_36[0][0]
# __________________________________________________________________________________________________
# block_3_dw_relu (ReLU)          (None, 32, 64, 144)  0           block_3_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_3_compress (Conv2D)       (None, 32, 64, 32)   4608        block_3_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_3_compress_bn (BatchNorma (None, 32, 64, 32)   128         block_3_compress[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 64, 192)  6144        block_3_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_4_expand_bn (BatchNormali (None, 32, 64, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_4_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_37 (DownSampling) (None, 32, 64, 192)  20112       block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_dw_bn (BatchNormalizati (None, 32, 64, 192)  768         down_sampling_37[0][0]
# __________________________________________________________________________________________________
# block_4_dw_relu (ReLU)          (None, 32, 64, 192)  0           block_4_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_4_compress (Conv2D)       (None, 32, 64, 32)   6144        block_4_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_4_compress_bn (BatchNorma (None, 32, 64, 32)   128         block_4_compress[0][0]
# __________________________________________________________________________________________________
# add_414 (Add)                   (None, 32, 64, 32)   0           block_3_compress_bn[0][0]
#                                                                  block_4_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 64, 192)  6144        add_414[0][0]
# __________________________________________________________________________________________________
# block_5_expand_bn (BatchNormali (None, 32, 64, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_5_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_38 (DownSampling) (None, 32, 64, 192)  20112       block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_dw_bn (BatchNormalizati (None, 32, 64, 192)  768         down_sampling_38[0][0]
# __________________________________________________________________________________________________
# block_5_dw_relu (ReLU)          (None, 32, 64, 192)  0           block_5_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_5_compress (Conv2D)       (None, 32, 64, 32)   6144        block_5_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_5_compress_bn (BatchNorma (None, 32, 64, 32)   128         block_5_compress[0][0]
# __________________________________________________________________________________________________
# add_415 (Add)                   (None, 32, 64, 32)   0           add_414[0][0]
#                                                                  block_5_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 64, 192)  6144        add_415[0][0]
# __________________________________________________________________________________________________
# block_6_expand_bn (BatchNormali (None, 32, 64, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_6_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_39 (DownSampling) (None, 16, 32, 192)  20112       block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_dw_bn (BatchNormalizati (None, 16, 32, 192)  768         down_sampling_39[0][0]
# __________________________________________________________________________________________________
# block_6_dw_relu (ReLU)          (None, 16, 32, 192)  0           block_6_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_6_compress (Conv2D)       (None, 16, 32, 64)   12288       block_6_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_6_compress_bn (BatchNorma (None, 16, 32, 64)   256         block_6_compress[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 32, 384)  24576       block_6_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_7_expand_bn (BatchNormali (None, 16, 32, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_7_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_40 (DownSampling) (None, 16, 32, 384)  77088       block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_dw_bn (BatchNormalizati (None, 16, 32, 384)  1536        down_sampling_40[0][0]
# __________________________________________________________________________________________________
# block_7_dw_relu (ReLU)          (None, 16, 32, 384)  0           block_7_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_7_compress (Conv2D)       (None, 16, 32, 64)   24576       block_7_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_7_compress_bn (BatchNorma (None, 16, 32, 64)   256         block_7_compress[0][0]
# __________________________________________________________________________________________________
# add_416 (Add)                   (None, 16, 32, 64)   0           block_6_compress_bn[0][0]
#                                                                  block_7_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 32, 384)  24576       add_416[0][0]
# __________________________________________________________________________________________________
# block_8_expand_bn (BatchNormali (None, 16, 32, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_8_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_41 (DownSampling) (None, 16, 32, 384)  77088       block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_dw_bn (BatchNormalizati (None, 16, 32, 384)  1536        down_sampling_41[0][0]
# __________________________________________________________________________________________________
# block_8_dw_relu (ReLU)          (None, 16, 32, 384)  0           block_8_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_8_compress (Conv2D)       (None, 16, 32, 64)   24576       block_8_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_8_compress_bn (BatchNorma (None, 16, 32, 64)   256         block_8_compress[0][0]
# __________________________________________________________________________________________________
# add_417 (Add)                   (None, 16, 32, 64)   0           add_416[0][0]
#                                                                  block_8_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 32, 384)  24576       add_417[0][0]
# __________________________________________________________________________________________________
# block_9_expand_bn (BatchNormali (None, 16, 32, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_9_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_42 (DownSampling) (None, 16, 32, 384)  77088       block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_dw_bn (BatchNormalizati (None, 16, 32, 384)  1536        down_sampling_42[0][0]
# __________________________________________________________________________________________________
# block_9_dw_relu (ReLU)          (None, 16, 32, 384)  0           block_9_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_9_compress (Conv2D)       (None, 16, 32, 64)   24576       block_9_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_9_compress_bn (BatchNorma (None, 16, 32, 64)   256         block_9_compress[0][0]
# __________________________________________________________________________________________________
# add_418 (Add)                   (None, 16, 32, 64)   0           add_417[0][0]
#                                                                  block_9_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 32, 384)  24576       add_418[0][0]
# __________________________________________________________________________________________________
# block_10_expand_bn (BatchNormal (None, 16, 32, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 32, 384)  0           block_10_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_43 (DownSampling) (None, 16, 32, 384)  77088       block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_dw_bn (BatchNormalizat (None, 16, 32, 384)  1536        down_sampling_43[0][0]
# __________________________________________________________________________________________________
# block_10_dw_relu (ReLU)         (None, 16, 32, 384)  0           block_10_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_10_compress (Conv2D)      (None, 16, 32, 96)   36864       block_10_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_10_compress_bn (BatchNorm (None, 16, 32, 96)   384         block_10_compress[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 32, 576)  55296       block_10_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_11_expand_bn (BatchNormal (None, 16, 32, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 32, 576)  0           block_11_expand_bn[0][0]
# __________________________________________________________________________________________________
# down_sampling_44 (DownSampling) (None, 16, 32, 576)  170928      block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_dw_bn (BatchNormalizat (None, 16, 32, 576)  2304        down_sampling_44[0][0]
# __________________________________________________________________________________________________
# block_11_dw_relu (ReLU)         (None, 16, 32, 576)  0           block_11_dw_bn[0][0]
# __________________________________________________________________________________________________
# block_11_compress (Conv2D)      (None, 16, 32, 96)   55296       block_11_dw_relu[0][0]
# __________________________________________________________________________________________________
# block_11_compress_bn (BatchNorm (None, 16, 32, 96)   384         block_11_compress[0][0]
# __________________________________________________________________________________________________
# add_419 (Add)                   (None, 16, 32, 96)   0           block_10_compress_bn[0][0]
#                                                                  block_11_compress_bn[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 32, 576)  55296       add_419[0][0]
# __________________________________________________________________________________________________
# block_13_expand_bn (BatchNormal (None, 16, 32, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 32, 576)  0           block_13_expand_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_2240 (Conv2D)            (None, 16, 32, 512)  295424      block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 16, 32, 512)  0           conv2d_2240[0][0]
# __________________________________________________________________________________________________
# up_sampling_50 (UpSampling)     (None, 32, 64, 256)  126080      leaky_re_lu_50[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 32, 64, 256)  0           up_sampling_50[0][0]
# __________________________________________________________________________________________________
# up_sampling_51 (UpSampling)     (None, 64, 128, 128) 35392       leaky_re_lu_51[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 64, 128, 128) 0           up_sampling_51[0][0]
# __________________________________________________________________________________________________
# up_sampling_52 (UpSampling)     (None, 128, 256, 64) 10016       leaky_re_lu_52[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 128, 256, 64) 0           up_sampling_52[0][0]
# __________________________________________________________________________________________________
# up_sampling_53 (UpSampling)     (None, 256, 512, 32) 1984        leaky_re_lu_53[0][0]
#                                                                  input_76[0][0]
# __________________________________________________________________________________________________
# conv2d_2257 (Conv2D)            (None, 256, 512, 1)  289         up_sampling_53[0][0]
# ==================================================================================================
# Total params: 1,505,849
# Trainable params: 1,481,865
# Non-trainable params: 23,984
# __________________________________________________________________________________________________

# %%
def upsampling(input_tensor, n_filters, concat_layer, concat=True):
  '''
  Block of Decoder
  '''
  # Bilinear 2x upsampling layer
  x = keras.layers.UpSampling2D(size=(2,2), interpolation='bilinear')(input_tensor)
  # concatenation with encoder block 
  if concat:
    x = keras.layers.concatenate([x, concat_layer])
  # decreasing the depth filters by half
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=(3,3), padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Conv2D(filters=n_filters, kernel_size=(3,3), padding='same')(x)
  x = keras.layers.BatchNormalization()(x)
  return x

def MobileNet():
    base_model = keras.applications.MobileNetV2(include_top=False, weights='imagenet', input_shape=(256, 512, 3))
    for layer in base_model.layers:
        layer.trainable = True

    inputs = base_model.input
    x = base_model.get_layer("block_13_expand_relu").output

    names = ["input_6", "block_1_expand_relu", "block_3_expand_relu", "block_6_expand_relu"][::-1]
    bneck = keras.layers.Conv2D(filters=512, kernel_size=(1,1), padding='same')(x)
    x = keras.layers.LeakyReLU(alpha=0.2)(bneck)
    x = upsampling(x, 256, base_model.get_layer(names[0]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = upsampling(x, 128, base_model.get_layer(names[1]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = upsampling(x, 64, base_model.get_layer(names[2]).output)
    x = keras.layers.LeakyReLU(alpha=0.2)(x)
    x = upsampling(x, 32, base_model.layers[0].output)
    x = keras.layers.Conv2D(filters=1, activation='sigmoid', kernel_size=(3,3), padding='same')(x)

    model = keras.Model(inputs=inputs, outputs=x)
    return model

model = MobileNet()
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_45"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_73 (InputLayer)           [(None, 256, 512, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 256, 32) 864         input_73[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 128, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 128, 256, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 128, 256, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 128, 256, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 128, 256, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 128, 256, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 128, 256, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 128, 256, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 128, 256, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 128, 256, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 129, 257, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 64, 128, 96)  864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 64, 128, 96)  384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 64, 128, 96)  0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 64, 128, 24)  2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 64, 128, 24)  96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 64, 128, 144) 3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 64, 128, 144) 576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 64, 128, 144) 0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 64, 128, 144) 1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 64, 128, 144) 576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 64, 128, 144) 0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 64, 128, 24)  3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 64, 128, 24)  96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 64, 128, 24)  0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 64, 128, 144) 3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 64, 128, 144) 576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 64, 128, 144) 0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 65, 129, 144) 0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 32, 64, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 32, 64, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 32, 64, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 32, 64, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 32, 64, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 32, 64, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 32, 64, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 32, 64, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 32, 64, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 32, 64, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 32, 64, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 32, 64, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 32, 64, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 32, 64, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 32, 64, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 32, 64, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 32, 64, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 32, 64, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 32, 64, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 32, 64, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 32, 64, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 32, 64, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 32, 64, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 32, 64, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 33, 65, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 16, 32, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 16, 32, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 16, 32, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 16, 32, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 16, 32, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 16, 32, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 16, 32, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 16, 32, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 16, 32, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 16, 32, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 16, 32, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 16, 32, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 16, 32, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 16, 32, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 16, 32, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 16, 32, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 16, 32, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 16, 32, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 16, 32, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 16, 32, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 16, 32, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 16, 32, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 16, 32, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 16, 32, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 16, 32, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 16, 32, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 16, 32, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 16, 32, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 16, 32, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 16, 32, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 16, 32, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 16, 32, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 16, 32, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 16, 32, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 16, 32, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 16, 32, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 16, 32, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 16, 32, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 16, 32, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 16, 32, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 16, 32, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 16, 32, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 16, 32, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 16, 32, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 16, 32, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 16, 32, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 16, 32, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 16, 32, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 16, 32, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 16, 32, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 16, 32, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 16, 32, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 16, 32, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 16, 32, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 16, 32, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 16, 32, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 16, 32, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 16, 32, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 16, 32, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# conv2d_2139 (Conv2D)            (None, 16, 32, 512)  295424      block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 16, 32, 512)  0           conv2d_2139[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 64, 512)  0           leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 64, 704)  0           up_sampling2d[0][0]
#                                                                  block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2140 (Conv2D)            (None, 32, 64, 256)  1622272     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1542 (Batch (None, 32, 64, 256)  1024        conv2d_2140[0][0]
# __________________________________________________________________________________________________
# conv2d_2141 (Conv2D)            (None, 32, 64, 256)  590080      batch_normalization_1542[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1543 (Batch (None, 32, 64, 256)  1024        conv2d_2141[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 32, 64, 256)  0           batch_normalization_1543[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 128, 256) 0           leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 128, 400) 0           up_sampling2d_1[0][0]
#                                                                  block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2142 (Conv2D)            (None, 64, 128, 128) 460928      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1544 (Batch (None, 64, 128, 128) 512         conv2d_2142[0][0]
# __________________________________________________________________________________________________
# conv2d_2143 (Conv2D)            (None, 64, 128, 128) 147584      batch_normalization_1544[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1545 (Batch (None, 64, 128, 128) 512         conv2d_2143[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 64, 128, 128) 0           batch_normalization_1545[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 256, 128 0           leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 256, 224 0           up_sampling2d_2[0][0]
#                                                                  block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# conv2d_2144 (Conv2D)            (None, 128, 256, 64) 129088      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1546 (Batch (None, 128, 256, 64) 256         conv2d_2144[0][0]
# __________________________________________________________________________________________________
# conv2d_2145 (Conv2D)            (None, 128, 256, 64) 36928       batch_normalization_1546[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1547 (Batch (None, 128, 256, 64) 256         conv2d_2145[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 128, 256, 64) 0           batch_normalization_1547[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 512, 64) 0           leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 512, 67) 0           up_sampling2d_3[0][0]
#                                                                  input_73[0][0]
# __________________________________________________________________________________________________
# conv2d_2146 (Conv2D)            (None, 256, 512, 32) 19328       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1548 (Batch (None, 256, 512, 32) 128         conv2d_2146[0][0]
# __________________________________________________________________________________________________
# conv2d_2147 (Conv2D)            (None, 256, 512, 32) 9248        batch_normalization_1548[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1549 (Batch (None, 256, 512, 32) 128         conv2d_2147[0][0]
# __________________________________________________________________________________________________
# conv2d_2148 (Conv2D)            (None, 256, 512, 1)  289         batch_normalization_1549[0][0]
# ==================================================================================================
# Total params: 3,931,265
# Trainable params: 3,912,065
# Non-trainable params: 19,200
# __________________________________________________________________________________________________
