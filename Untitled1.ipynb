# %%
import numpy as np

vals = ['ssim l1',
 'ssim l1 berhu sobel edges',
 'ssim berhu',
 'ssim berhu sobel edges smooth',
 'ssim sobel edges smooth',
 'ssim berhu sobel',
 'ssim berhu sobel edges',
 'ssim l1 sobel edges smooth',
 'ssim sobel',
 'ssim berhu smooth',
 'ssim l1 sobel smooth',
 'ssim l1 berhu edges smooth',
 'ssim l1 edges',
 'ssim l1 berhu sobel edges smooth',
 'edges',
 'ssim berhu edges smooth',
 'ssim sobel edges',
 'ssim l1 berhu edges',
 'ssim l1 berhu sobel smooth',
 'sobel',
 'smooth',
 'ssim l1 sobel',
 'ssim berhu sobel smooth',
 'l1',
 'berhu',
 'ssim l1 smooth',
 'ssim edges smooth',
 'ssim l1 berhu',
 'ssim sobel smooth',
 'ssim edges',
 'ssim l1 berhu smooth',
 'ssim l1 berhu sobel',
 'ssim',
 'ssim l1 sobel edges',
 'ssim berhu edges',
 'ssim l1 edges smooth',
 'ssim smooth']

# %%
data = []

vals = ['ssim l1',
 'ssim l1 berhu sobel edges',
 'ssim berhu',
 'ssim berhu sobel edges smooth',
 'ssim sobel edges smooth',
 'ssim berhu sobel',
 'ssim berhu sobel edges',
 'ssim l1 sobel edges smooth',
 'ssim sobel',
 'ssim berhu smooth',
 'ssim l1 sobel smooth',
 'ssim l1 berhu edges smooth',
 'ssim l1 edges',
 'ssim l1 berhu sobel edges smooth',
 'edges',
 'ssim berhu edges smooth',
 'ssim sobel edges',
 'ssim l1 berhu edges',
 'ssim l1 berhu sobel smooth',
 'sobel',
 'smooth',
 'ssim l1 sobel',
 'ssim berhu sobel smooth',
 'l1',
 'berhu',
 'ssim l1 smooth',
 'ssim edges smooth',
 'ssim l1 berhu',
 'ssim sobel smooth',
 'ssim edges',
 'ssim l1 berhu smooth',
 'ssim l1 berhu sobel',
 'ssim',
 'ssim l1 sobel edges',
 'ssim berhu edges',
 'ssim l1 edges smooth',
 'ssim smooth']

for v in vals:
    v = v.split(" ")
    d = "_".join(v)
    data.append(f"./result/shuffle_pano_skip_scene_sigmoid_{d}.h5")
# Out:
# ['./result/shuffle_pano_skip_scene_sigmoid_ssim_l1.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_sobel_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_sobel_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_sobel_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_sobel.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_sobel_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_sobel_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_sobel.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_sobel_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_sobel_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_sobel_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_sobel_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_sobel.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_sobel.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_sobel_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_l1.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_berhu.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_sobel_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_berhu_sobel.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_sobel_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_berhu_edges.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_l1_edges_smooth.h5',
#  './result/shuffle_pano_skip_scene_sigmoid_ssim_smooth.h5']
